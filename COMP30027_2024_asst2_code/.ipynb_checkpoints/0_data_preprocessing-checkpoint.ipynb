# %% [markdown]
# ## 0. Data preprocess
#
# ##### Since dataset contains many different types of features, require preprocess the data.

# %%
# import useful library
import numpy as np
import pandas as pd
from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import mutual_info_regression
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

# %%
# import datasets
train_data = pd.read_csv("../COMP30027_2024_asst2_data/train_dataset.csv")
test_data = pd.read_csv("../COMP30027_2024_asst2_data/test_dataset.csv")


# count CountVectorizer features for director names, actor names, and possibly other text features
cv_path = "../COMP30027_2024_asst2_data/features_countvec/"
cvtrain_director_name = np.load(cv_path + "train_countvec_features_director_name.npy")
cvtrain_actor_1_name = np.load(cv_path + "train_countvec_features_actor_1_name.npy")
cvtrain_actor_2_name = np.load(cv_path + "train_countvec_features_actor_2_name.npy")

cvtest_director_name = np.load(cv_path + "test_countvec_features_director_name.npy")
cvtest_actor_1_name = np.load(cv_path + "test_countvec_features_actor_1_name.npy")
cvtest_actor_2_name = np.load(cv_path + "test_countvec_features_actor_2_name.npy")

# Doc2Vec features for plot keywords, genres, and other text features
d2v_path = "../COMP30027_2024_asst2_data/features_doc2vec/"
d2vtrain_plot = np.load(d2v_path + "train_doc2vec_features_plot_keywords.npy")
d2vtrain_genre = np.load(d2v_path + "train_doc2vec_features_genre.npy")
d2vtest_plot = np.load(d2v_path + "test_doc2vec_features_plot_keywords.npy")
d2vtest_genre = np.load(d2v_path + "test_doc2vec_features_genre.npy")

# FastText embeddings for movie titles
ft_path = "../COMP30027_2024_asst2_data/features_fasttext/"
fttrain_title = np.load(ft_path + "train_fasttext_title_embeddings.npy")
fttest_title = np.load(ft_path + "test_fasttext_title_embeddings.npy")

# %%
# handle missing values
missing_counts = train_data.isnull().sum()
print(missing_counts)
missing_row = train_data[train_data['language'].isnull()]
print(missing_row)
# as the language of a movie called "Labor Day" that the country is USA, good chance English
train_data.loc[2787, 'language'] = 'English'
# Out:
# id                           0
# director_name                0
# num_critic_for_reviews       0
# duration                     0
# director_facebook_likes      0
# actor_3_facebook_likes       0
# actor_2_name                 0
# actor_1_facebook_likes       0
# gross                        0
# genres                       0
# actor_1_name                 0
# movie_title                  0
# num_voted_users              0
# cast_total_facebook_likes    0
# actor_3_name                 0
# facenumber_in_poster         0
# plot_keywords                0
# num_user_for_reviews         0
# language                     1
# country                      0
# content_rating               0
# title_year                   0
# actor_2_facebook_likes       0
# movie_facebook_likes         0
# title_embedding              0
# average_degree_centrality    0
# imdb_score_binned            0
# dtype: int64
#         id director_name  num_critic_for_reviews  duration  \
# 2787  2788    Ron Fricke                     115       102
#
#       director_facebook_likes  actor_3_facebook_likes  \
# 2787                      330                       0
#
#                       actor_2_name  actor_1_facebook_likes    gross  \
# 2787  Balinese Tari Legong Dancers                      48  2601847
#
#                  genres  ... num_user_for_reviews language  country  \
# 2787  Documentary|Music  ...                   69      NaN      USA
#
#       content_rating title_year  actor_2_facebook_likes movie_facebook_likes  \
# 2787           PG-13       2011                       0                26000
#
#                                         title_embedding  \
# 2787  [-1.7939140e-04  1.7596362e-03 -8.5148757e-05 ...
#
#      average_degree_centrality imdb_score_binned
# 2787                    0.0003                 4
#
# [1 rows x 27 columns]

# %%
# generate a simple numerical dataset for baseline models
# starting by remove all text column
# for non numerical feature, convert to numerical
le = LabelEncoder()
train_data['language'] = le.fit_transform(train_data['language'])
train_data['country'] = le.fit_transform(train_data['country'])
train_data['content_rating'] = le.fit_transform(train_data['content_rating'])

test_data['language'] = le.fit_transform(test_data['language'])
test_data['country'] = le.fit_transform(test_data['country'])
test_data['content_rating'] = le.fit_transform(test_data['content_rating'])

# %%
print("unique attribute count")
print("director name: ", train_data['director_name'].unique().shape)
print("actor 1 name: ", train_data['actor_1_name'].unique().shape)
print("actor 2 name: ", train_data['actor_2_name'].unique().shape)
print("actor 3 name: ", train_data['actor_3_name'].unique().shape)
print("title: ", train_data['movie_title'].unique().shape)
# Out:
# unique attribute count
# director name:  (1460,)
# actor 1 name:  (1265,)
# actor 2 name:  (1903,)
# actor 3 name:  (2198,)
# title:  (2942,)

# %%
# check mutual info
encoded = le.fit_transform(train_data['director_name'].copy())
mi_score = mutual_info_classif(encoded.reshape(-1, 1), train_data['imdb_score_binned'], random_state=715)
print('mi score director name:', mi_score[0])

encoded = le.fit_transform(train_data['actor_1_name'].copy())
mi_score = mutual_info_classif(encoded.reshape(-1, 1), train_data['imdb_score_binned'], random_state=715)
print('mi score actor1 name:', mi_score[0])

encoded = le.fit_transform(train_data['actor_2_name'].copy())
mi_score = mutual_info_classif(encoded.reshape(-1, 1), train_data['imdb_score_binned'], random_state=715)
print('mi score actor2 name:', mi_score[0])

encoded = le.fit_transform(train_data['actor_3_name'].copy())
mi_score = mutual_info_classif(encoded.reshape(-1, 1), train_data['imdb_score_binned'], random_state=715)
print('mi score actor3 name:', mi_score[0])

encoded = le.fit_transform(train_data['movie_title'].copy())
mi_score = mutual_info_classif(encoded.reshape(-1, 1), train_data['imdb_score_binned'], random_state=715)
print('mi score movie title:', mi_score[0])
# Out:
# mi score director name: 0
# mi score actor1 name: 0
# mi score actor2 name: 0
# mi score actor3 name: 0
# mi score movie title: 0

# %%
# as those columns contain quite a lot unique values, and they are text based which is hard to process
# generate a train set that just discard them
# by logic, movie genre and plot_keyword should not interfere with rating, test the accuracy if drop them
columns_to_drop = ['director_name', 'actor_1_name', 'actor_2_name', 'actor_3_name', 'movie_title', 'genres', 'plot_keywords', 'title_embedding']
train_data_no_text = train_data.drop(columns=columns_to_drop)
test_data_no_text = test_data.drop(columns=columns_to_drop)

train_data_no_text.to_csv("../COMP30027_2024_asst2_data/train_dataset_no_text.csv", index=False)
test_data_no_text.to_csv("../COMP30027_2024_asst2_data/test_dataset_no_text.csv", index=False)

# %%
# check data distributions
summary = train_data_no_text.describe(include='all')
test_summary = test_data_no_text.describe(include='all')
print(summary)
print("-----")
print(test_summary)
# as large scale in the dataset, and there are some outlier in facebook likes datas
# stardardization is possibly better
# Out:
#                id  num_critic_for_reviews     duration  \
# count  3004.00000             3004.000000  3004.000000
# mean   1502.50000              165.609188   110.076565
# std     867.32443              121.254549    21.910608
# min       1.00000                2.000000    37.000000
# 25%     751.75000               76.000000    96.000000
# 50%    1502.50000              137.000000   106.000000
# 75%    2253.25000              223.000000   120.000000
# max    3004.00000              813.000000   330.000000
#
#        director_facebook_likes  actor_3_facebook_likes  \
# count              3004.000000             3004.000000
# mean                778.890146              767.860186
# std                2990.741946             1901.991202
# min                   0.000000                0.000000
# 25%                  10.000000              191.000000
# 50%                  62.500000              433.000000
# 75%                 234.000000              683.000000
# max               23000.000000            23000.000000
#
#        actor_1_facebook_likes         gross  num_voted_users  \
# count             3004.000000  3.004000e+03     3.004000e+03
# mean              7654.935752  5.187733e+07     1.049017e+05
# std              16488.761947  6.840156e+07     1.508573e+05
# min                  0.000000  1.620000e+02     9.100000e+01
# 25%                728.500000  8.579684e+06     1.897825e+04
# 50%               1000.000000  3.020586e+07     5.387400e+04
# 75%              12000.000000  6.647359e+07     1.284895e+05
# max             640000.000000  6.586723e+08     1.689764e+06
#
#        cast_total_facebook_likes  facenumber_in_poster  num_user_for_reviews  \
# count                3004.000000           3004.000000           3004.000000
# mean                11391.643808              1.380826            335.922770
# std                 20044.723195              2.093417            415.219466
# min                     0.000000              0.000000              4.000000
# 25%                  1873.000000              0.000000            108.000000
# 50%                  3889.000000              1.000000            208.000000
# 75%                 15925.250000              2.000000            398.000000
# max                656730.000000             43.000000           5060.000000
#
#           language      country  content_rating   title_year  \
# count  3004.000000  3004.000000      3004.00000  3004.000000
# mean      9.320905    36.906125         7.59221  2002.782956
# std       2.246887     8.720195         1.68196    10.086250
# min       0.000000     0.000000         0.00000  1929.000000
# 25%       9.000000    40.000000         7.00000  1999.000000
# 50%       9.000000    40.000000         7.00000  2004.000000
# 75%       9.000000    40.000000         9.00000  2010.000000
# max      31.000000    41.000000        11.00000  2016.000000
#
#        actor_2_facebook_likes  movie_facebook_likes  \
# count             3004.000000           3004.000000
# mean              1992.843209           8972.179427
# std               4651.072554          19853.888300
# min                  0.000000              0.000000
# 25%                377.750000              0.000000
# 50%                664.000000            241.000000
# 75%                970.000000          11000.000000
# max             137000.000000         197000.000000
#
#        average_degree_centrality  imdb_score_binned
# count                3004.000000        3004.000000
# mean                    0.001739           2.250333
# std                     0.001183           0.691451
# min                     0.000300           0.000000
# 25%                     0.000825           2.000000
# 50%                     0.001426           2.000000
# 75%                     0.002401           3.000000
# max                     0.007354           4.000000
# -----
#                id  num_critic_for_reviews    duration  \
# count  752.000000              752.000000  752.000000
# mean   376.500000              174.445479  110.982713
# std    217.227991              131.713383   25.378172
# min      1.000000                8.000000   63.000000
# 25%    188.750000               81.750000   96.000000
# 50%    376.500000              142.000000  106.000000
# 75%    564.250000              229.250000  119.000000
# max    752.000000              775.000000  325.000000
#
#        director_facebook_likes  actor_3_facebook_likes  \
# count               752.000000              752.000000
# mean                920.970745              784.938830
# std                3359.461455             1864.192618
# min                   0.000000                0.000000
# 25%                  14.000000              203.500000
# 50%                  66.500000              457.000000
# 75%                 243.250000              722.250000
# max               22000.000000            19000.000000
#
#        actor_1_facebook_likes         gross  num_voted_users  \
# count              752.000000  7.520000e+02     7.520000e+02
# mean              8136.437500  5.555090e+07     1.095218e+05
# std              10812.436334  7.748123e+07     1.567015e+05
# min                  2.000000  7.030000e+02     4.800000e+02
# 25%                817.500000  6.852100e+06     2.314025e+04
# 50%               2000.000000  2.916831e+07     5.424550e+04
# 75%              13250.000000  6.947862e+07     1.289892e+05
# max             137000.000000  7.605058e+08     1.347461e+06
#
#        cast_total_facebook_likes  facenumber_in_poster  num_user_for_reviews  \
# count                 752.000000            752.000000            752.000000
# mean                12068.214096              1.363032            340.519947
# std                 14875.918668              1.820834            395.124750
# min                     2.000000              0.000000              6.000000
# 25%                  2027.750000              0.000000            116.000000
# 50%                  4660.000000              1.000000            218.500000
# 75%                 17513.500000              2.000000            402.000000
# max                140268.000000             15.000000           3054.000000
#
#          language     country  content_rating   title_year  \
# count  752.000000  752.000000      752.000000   752.000000
# mean     1.223404   21.139628        5.622340  2003.750000
# std      1.406882    5.264045        1.480789     9.018327
# min      0.000000    0.000000        0.000000  1927.000000
# 25%      1.000000   23.000000        5.000000  1999.000000
# 50%      1.000000   23.000000        5.000000  2005.000000
# 75%      1.000000   23.000000        7.000000  2010.000000
# max     14.000000   23.000000        9.000000  2016.000000
#
#        actor_2_facebook_likes  movie_facebook_likes  average_degree_centrality
# count              752.000000            752.000000                 752.000000
# mean              2137.352394          10878.398936                   0.001839
# std               4094.280342          26910.692305                   0.001230
# min                  0.000000              0.000000                   0.000300
# 25%                417.000000              0.000000                   0.000825
# 50%                731.000000            172.500000                   0.001501
# 75%               1000.000000          12000.000000                   0.002551
# max              27000.000000         349000.000000                   0.006754
