# %% [markdown]
# ## 0. Data preprocess
#
# ##### Since dataset contains many different types of features, require preprocess the data.

# %%
# import useful library
import numpy as np
import pandas as df

import matplotlib as plt

# %%
# import datasets
train_data = pd.read_csv("../COMP30027_2024_asst2_data/train_dataset.csv")
test_data = pd.read_csv("../COMP30027_2024_asst2_data/test_dataset.csv")

df.summary(train_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       2 train_data = pd.read_csv("../COMP30027_2024_asst2_data/train_dataset.csv")
#       3 test_data = pd.read_csv("../COMP30027_2024_asst2_data/test_dataset.csv")
# ----> 5 df.summary(train_data)
#
# NameError: name 'df' is not defined
