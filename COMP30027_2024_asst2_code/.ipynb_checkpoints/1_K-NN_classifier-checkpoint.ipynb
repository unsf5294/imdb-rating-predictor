# %% [markdown]
# ### 1. K-NN model
# ##### This model serves as a baseline model for classification problem

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score

# %%
# first use the basic no text data
data = pd.read_csv("../COMP30027_2024_asst2_data/train_dataset_no_text.csv")
test_data = pd.read_csv("../COMP30027_2024_asst2_data/test_dataset_no_text.csv")

# %%
# split the data
X = data.drop(columns=["imdb_score_binned"])
y = data["imdb_score_binned"]

# fix array datatype problem
# found this usage on web
X_np = np.ascontiguousarray(X.to_numpy())
y_np = np.ascontiguousarray(y.to_numpy())

# knn k=5
knn = KNeighborsClassifier(n_neighbors=5)

# cross validation
cv_scores = cross_val_score(knn, X_np, y_np, cv=10, scoring='accuracy')
print('mean of cross validation with 10 fold:', cv_scores.mean())
print('variance:', cv_scores.std())
# Out:
# mean of cross validation with 10 fold: 0.6371328903654485
# variance: 0.0198432885767261

# %%
# make prediction on test
knn_test = KNeighborsClassifier(n_neighbors=5)
knn_test.fit(X_np, y_np)
test_np = np.ascontiguousarray(test_data.to_numpy())
test_pred = knn_test.predict(test_np)
ids = range(1, len(test_pred) + 1)

# save submission file
pred = pd.DataFrame({'id': ids, 'imdb_score_binned': test_pred})
pred.to_csv("../Kaggle_submissions/knn_no_text.csv", index=False)
