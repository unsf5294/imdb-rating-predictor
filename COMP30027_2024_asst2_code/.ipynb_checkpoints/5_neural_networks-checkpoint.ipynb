# %% [markdown]
# ### 5. Neural networks
# ##### Explore varies neural networks using keras library.

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping

# %%
# first use the basic no text data
data = pd.read_csv("../COMP30027_2024_asst2_data/train_dataset_no_text.csv")
test_data = pd.read_csv("../COMP30027_2024_asst2_data/test_dataset_no_text.csv")
# drop id before calculation, add back after
data = data.drop(columns='id')
test_data = test_data.drop(columns='id')

# %%
# split the data
X = data.drop(columns=["imdb_score_binned"])
y = data["imdb_score_binned"]



X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=715)

# set up scalers
mmscaler = MinMaxScaler()
ssscaler = StandardScaler()


mmX_train = mmscaler.fit_transform(X_train)
mmX_test = mmscaler.transform(X_test)
ssX_train = ssscaler.fit_transform(X_train)
ssX_test = ssscaler.transform(X_test)

# %%
# design nn
model = Sequential([
    Dense(32, input_shape=(X_train.shape[1],), activation='relu'),
    Dense(16, activation='sigmoid'),
    Dense(y.nunique(), activation='softmax')
])

# instantiate
model.compile(optimizer='nadam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit(ssX_train, y_train, epochs=50, batch_size=32, validation_split=0.1, callbacks=[early_stopping])


# get accuracy
test_loss, test_acc = model.evaluate(ssX_test, y_test)
print("Test Accuracy:" ,test_acc)
# Out:
# Epoch 1/50
# 68/68 [==============================] - 1s 3ms/step - loss: 1.2195 - accuracy: 0.6078 - val_loss: 1.0762 - val_accuracy: 0.6100
# Epoch 2/50
# 68/68 [==============================] - 0s 1ms/step - loss: 1.0309 - accuracy: 0.6161 - val_loss: 0.9779 - val_accuracy: 0.6224
# Epoch 3/50
# 68/68 [==============================] - 0s 1ms/step - loss: 0.9664 - accuracy: 0.6332 - val_loss: 0.9273 - val_accuracy: 0.6349
# Epoch 4/50
# 68/68 [==============================] - 0s 1ms/step - loss: 0.9248 - accuracy: 0.6392 - val_loss: 0.8911 - val_accuracy: 0.6349
# Epoch 5/50
# 68/68 [==============================] - 0s 1ms/step - loss: 0.8918 - accuracy: 0.6549 - val_loss: 0.8577 - val_accuracy: 0.6556
# Epoch 6/50
# 68/68 [==============================] - 0s 1ms/step - loss: 0.8629 - accuracy: 0.6660 - val_loss: 0.8342 - val_accuracy: 0.6639
# Epoch 7/50
# 68/68 [==============================] - 0s 1ms/step - loss: 0.8398 - accuracy: 0.6716 - val_loss: 0.8129 - val_accuracy: 0.6805
# Epoch 8/50
# 68/68 [==============================] - 0s 1ms/step - loss: 0.8216 - accuracy: 0.6832 - val_loss: 0.7970 - val_accuracy: 0.6722
# Epoch 9/50
# 68/68 [==============================] - 0s 1ms/step - loss: 0.8066 - accuracy: 0.6892 - val_loss: 0.7839 - val_accuracy: 0.6763
# Epoch 10/50
# 68/68 [==============================] - 0s 1ms/step - loss: 0.7924 - accuracy: 0.6984 - val_loss: 0.7720 - val_accuracy: 0.6888
# Epoch 11/50
# 68/68 [==============================] - 0s 1ms/step - loss: 0.7816 - accuracy: 0.7031 - val_loss: 0.7660 - val_accuracy: 0.7054
# Epoch 12/50
# 68/68 [==============================] - 0s 1ms/step - loss: 0.7717 - accuracy: 0.7049 - val_loss: 0.7558 - val_accuracy: 0.7012
# Epoch 13/50
# 68/68 [==============================] - 0s 1ms/step - loss: 0.7632 - accuracy: 0.7091 - val_loss: 0.7490 - val_accuracy: 0.7054
# Epoch 14/50
# 68/68 [==============================] - 0s 1ms/step - loss: 0.7550 - accuracy: 0.7165 - val_loss: 0.7406 - val_accuracy: 0.7095
# Epoch 15/50
# 68/68 [==============================] - 0s 1ms/step - loss: 0.7490 - accuracy: 0.7118 - val_loss: 0.7333 - val_accuracy: 0.7012
# Epoch 16/50
# 68/68 [==============================] - 0s 2ms/step - loss: 0.7410 - accuracy: 0.7151 - val_loss: 0.7304 - val_accuracy: 0.7012
# Epoch 17/50
# 68/68 [==============================] - 0s 1ms/step - loss: 0.7353 - accuracy: 0.7137 - val_loss: 0.7261 - val_accuracy: 0.7054
# Epoch 18/50
# 68/68 [==============================] - 0s 1ms/step - loss: 0.7301 - accuracy: 0.7179 - val_loss: 0.7226 - val_accuracy: 0.7137
# Epoch 19/50
# 68/68 [==============================] - 0s 1ms/step - loss: 0.7250 - accuracy: 0.7202 - val_loss: 0.7212 - val_accuracy: 0.7095
# Epoch 20/50
# 68/68 [==============================] - 0s 1ms/step - loss: 0.7213 - accuracy: 0.7206 - val_loss: 0.7178 - val_accuracy: 0.7137
# Epoch 21/50
# 68/68 [==============================] - 0s 2ms/step - loss: 0.7163 - accuracy: 0.7206 - val_loss: 0.7165 - val_accuracy: 0.7137
# Epoch 22/50
# 68/68 [==============================] - 0s 1ms/step - loss: 0.7123 - accuracy: 0.7188 - val_loss: 0.7134 - val_accuracy: 0.7095
# Epoch 23/50
# 68/68 [==============================] - 0s 1ms/step - loss: 0.7078 - accuracy: 0.7243 - val_loss: 0.7091 - val_accuracy: 0.7137
# Epoch 24/50
# 68/68 [==============================] - 0s 1ms/step - loss: 0.7045 - accuracy: 0.7220 - val_loss: 0.7124 - val_accuracy: 0.7095
# Epoch 25/50
# 68/68 [==============================] - 0s 1ms/step - loss: 0.7009 - accuracy: 0.7234 - val_loss: 0.7082 - val_accuracy: 0.7137
# Epoch 26/50
# 68/68 [==============================] - 0s 1ms/step - loss: 0.6984 - accuracy: 0.7253 - val_loss: 0.7075 - val_accuracy: 0.7095
# Epoch 27/50
# 68/68 [==============================] - 0s 1ms/step - loss: 0.6943 - accuracy: 0.7285 - val_loss: 0.7074 - val_accuracy: 0.7012
# Epoch 28/50
# 68/68 [==============================] - 0s 1ms/step - loss: 0.6910 - accuracy: 0.7266 - val_loss: 0.7028 - val_accuracy: 0.7178
# Epoch 29/50
# 68/68 [==============================] - 0s 1ms/step - loss: 0.6880 - accuracy: 0.7206 - val_loss: 0.7041 - val_accuracy: 0.7137
# Epoch 30/50
# 68/68 [==============================] - 0s 1ms/step - loss: 0.6860 - accuracy: 0.7280 - val_loss: 0.7005 - val_accuracy: 0.7095
# Epoch 31/50
# 68/68 [==============================] - 0s 1ms/step - loss: 0.6819 - accuracy: 0.7266 - val_loss: 0.6979 - val_accuracy: 0.7137
# Epoch 32/50
# 68/68 [==============================] - 0s 1ms/step - loss: 0.6799 - accuracy: 0.7266 - val_loss: 0.6970 - val_accuracy: 0.7261
# Epoch 33/50
# 68/68 [==============================] - 0s 1ms/step - loss: 0.6768 - accuracy: 0.7294 - val_loss: 0.6965 - val_accuracy: 0.7178
# Epoch 34/50
# 68/68 [==============================] - 0s 1ms/step - loss: 0.6748 - accuracy: 0.7266 - val_loss: 0.6940 - val_accuracy: 0.7178
# Epoch 35/50
# 68/68 [==============================] - 0s 1ms/step - loss: 0.6707 - accuracy: 0.7317 - val_loss: 0.6945 - val_accuracy: 0.7178
# Epoch 36/50
# 68/68 [==============================] - 0s 1ms/step - loss: 0.6701 - accuracy: 0.7266 - val_loss: 0.6901 - val_accuracy: 0.7220
# Epoch 37/50
# 68/68 [==============================] - 0s 1ms/step - loss: 0.6662 - accuracy: 0.7290 - val_loss: 0.6907 - val_accuracy: 0.7261
# Epoch 38/50
# 68/68 [==============================] - 0s 1ms/step - loss: 0.6647 - accuracy: 0.7340 - val_loss: 0.6926 - val_accuracy: 0.7303
# Epoch 39/50
# 68/68 [==============================] - 0s 1ms/step - loss: 0.6616 - accuracy: 0.7345 - val_loss: 0.6918 - val_accuracy: 0.7220
# Epoch 40/50
# 68/68 [==============================] - 0s 1ms/step - loss: 0.6591 - accuracy: 0.7317 - val_loss: 0.6893 - val_accuracy: 0.7220
# Epoch 41/50
# 68/68 [==============================] - 0s 1ms/step - loss: 0.6576 - accuracy: 0.7345 - val_loss: 0.6869 - val_accuracy: 0.7178
# Epoch 42/50
# 68/68 [==============================] - 0s 1ms/step - loss: 0.6537 - accuracy: 0.7359 - val_loss: 0.6871 - val_accuracy: 0.7220
# Epoch 43/50
# 68/68 [==============================] - 0s 1ms/step - loss: 0.6529 - accuracy: 0.7313 - val_loss: 0.6846 - val_accuracy: 0.7261
# Epoch 44/50
# 68/68 [==============================] - 0s 1ms/step - loss: 0.6505 - accuracy: 0.7368 - val_loss: 0.6833 - val_accuracy: 0.7261
# Epoch 45/50
# 68/68 [==============================] - 0s 1ms/step - loss: 0.6480 - accuracy: 0.7354 - val_loss: 0.6823 - val_accuracy: 0.7303
# Epoch 46/50
# 68/68 [==============================] - 0s 1ms/step - loss: 0.6462 - accuracy: 0.7377 - val_loss: 0.6820 - val_accuracy: 0.7344
# Epoch 47/50
# 68/68 [==============================] - 0s 1ms/step - loss: 0.6442 - accuracy: 0.7396 - val_loss: 0.6796 - val_accuracy: 0.7220
# Epoch 48/50
# 68/68 [==============================] - 0s 1ms/step - loss: 0.6424 - accuracy: 0.7387 - val_loss: 0.6799 - val_accuracy: 0.7178
# Epoch 49/50
# 68/68 [==============================] - 0s 1ms/step - loss: 0.6415 - accuracy: 0.7373 - val_loss: 0.6820 - val_accuracy: 0.7261
# Epoch 50/50
# 68/68 [==============================] - 0s 1ms/step - loss: 0.6389 - accuracy: 0.7373 - val_loss: 0.6785 - val_accuracy: 0.7220
# 19/19 [==============================] - 0s 944us/step - loss: 0.7558 - accuracy: 0.7055
# Test Accuracy: 0.7054908275604248

# %% [markdown]
# #### Kaggle prediction on test data

# %%
mmX = mmscaler.fit_transform(X)
ssX = ssscaler.fit_transform(X)
sstest_data = ssscaler.transform(test_data)

history = model.fit(ssX, y, epochs=20, batch_size=32, validation_split=0.2, callbacks=[early_stopping])
# Out:
# Epoch 1/20
# 76/76 [==============================] - 0s 2ms/step - loss: 0.6604 - accuracy: 0.7316 - val_loss: 0.6746 - val_accuracy: 0.7354
# Epoch 2/20
# 76/76 [==============================] - 0s 1ms/step - loss: 0.6572 - accuracy: 0.7316 - val_loss: 0.6810 - val_accuracy: 0.7338
# Epoch 3/20
# 76/76 [==============================] - 0s 1ms/step - loss: 0.6533 - accuracy: 0.7337 - val_loss: 0.6769 - val_accuracy: 0.7354
# Epoch 4/20
# 76/76 [==============================] - 0s 1ms/step - loss: 0.6510 - accuracy: 0.7312 - val_loss: 0.6862 - val_accuracy: 0.7271
# Epoch 5/20
# 76/76 [==============================] - 0s 1ms/step - loss: 0.6495 - accuracy: 0.7362 - val_loss: 0.6792 - val_accuracy: 0.7371
# Epoch 6/20
# 76/76 [==============================] - 0s 1ms/step - loss: 0.6476 - accuracy: 0.7341 - val_loss: 0.6826 - val_accuracy: 0.7304
# Epoch 7/20
# 76/76 [==============================] - 0s 1ms/step - loss: 0.6446 - accuracy: 0.7349 - val_loss: 0.6807 - val_accuracy: 0.7388
# Epoch 8/20
# 76/76 [==============================] - 0s 1ms/step - loss: 0.6441 - accuracy: 0.7374 - val_loss: 0.6881 - val_accuracy: 0.7238
# Epoch 9/20
# 76/76 [==============================] - 0s 1ms/step - loss: 0.6414 - accuracy: 0.7370 - val_loss: 0.6915 - val_accuracy: 0.7304
# Epoch 10/20
# 76/76 [==============================] - 0s 1ms/step - loss: 0.6390 - accuracy: 0.7370 - val_loss: 0.6823 - val_accuracy: 0.7271
# Epoch 11/20
# 76/76 [==============================] - 0s 1ms/step - loss: 0.6371 - accuracy: 0.7403 - val_loss: 0.6832 - val_accuracy: 0.7304

# %%
test_pred = model.predict(test_data)
test_pred = test_pred.argmax(axis=1)
ids = range(1, len(test_pred) + 1)

# save submission file
prediction = pd.DataFrame({'id': ids, 'imdb_score_binned': test_pred})
print(prediction['imdb_score_binned'].value_counts())
prediction.to_csv("../Kaggle_submissions/dense_nn_select_feature.csv", index=False)
# Out:
# 24/24 [==============================] - 0s 957us/step
# imdb_score_binned
# 2    724
# 4     14
# 3     14
# Name: count, dtype: int64

# %% [markdown]
# ### 5.2

# %%
data = pd.read_csv("../COMP30027_2024_asst2_data/train_select.csv")
# drop id before calculation, add back after
data = data.drop(columns='id')

# %%
# split the data
X = data.drop(columns=["imdb_score_binned"])
y = data["imdb_score_binned"]

# set up scalers
mmscaler = MinMaxScaler()
ssscaler = StandardScaler()

mmscaler.fit(X)
ssscaler.fit(X)

mmX = mmscaler.transform(X)
ssX = ssscaler.transform(X)

X_train, X_test, y_train, y_test = train_test_split(ssX, y, test_size=0.2, random_state=715)

# %%
# design nn
model = Sequential([
    Dense(32, input_shape=(X_train.shape[1],), activation='relu'),
    Dense(16, activation='relu'), 
    Dense(y.nunique(), activation='softmax')
])

# instantiate
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2)

# get accuracy
test_loss, test_acc = model.evaluate(X_test, y_test)  # Make sure to transform X_test with the same scaler used on X_train
print("Test Accuracy:" ,test_acc)
# Out:
# Epoch 1/50
# 61/61 [==============================] - 1s 3ms/step - loss: 1.4764 - accuracy: 0.5094 - val_loss: 1.2306 - val_accuracy: 0.6299
# Epoch 2/50
# 61/61 [==============================] - 0s 2ms/step - loss: 1.1713 - accuracy: 0.6077 - val_loss: 1.0777 - val_accuracy: 0.6320
# Epoch 3/50
# 61/61 [==============================] - 0s 1ms/step - loss: 1.0551 - accuracy: 0.6160 - val_loss: 0.9939 - val_accuracy: 0.6362
# Epoch 4/50
# 61/61 [==============================] - 0s 1ms/step - loss: 0.9781 - accuracy: 0.6327 - val_loss: 0.9246 - val_accuracy: 0.6466
# Epoch 5/50
# 61/61 [==============================] - 0s 1ms/step - loss: 0.9159 - accuracy: 0.6478 - val_loss: 0.8735 - val_accuracy: 0.6528
# Epoch 6/50
# 61/61 [==============================] - 0s 1ms/step - loss: 0.8618 - accuracy: 0.6602 - val_loss: 0.8367 - val_accuracy: 0.6653
# Epoch 7/50
# 61/61 [==============================] - 0s 1ms/step - loss: 0.8213 - accuracy: 0.6785 - val_loss: 0.7984 - val_accuracy: 0.6778
# Epoch 8/50
# 61/61 [==============================] - 0s 1ms/step - loss: 0.7895 - accuracy: 0.6868 - val_loss: 0.7883 - val_accuracy: 0.6861
# Epoch 9/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.7662 - accuracy: 0.6977 - val_loss: 0.7747 - val_accuracy: 0.7006
# Epoch 10/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.7480 - accuracy: 0.7019 - val_loss: 0.7641 - val_accuracy: 0.7006
# Epoch 11/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.7341 - accuracy: 0.7112 - val_loss: 0.7624 - val_accuracy: 0.7069
# Epoch 12/50
# 61/61 [==============================] - 0s 1ms/step - loss: 0.7208 - accuracy: 0.7144 - val_loss: 0.7567 - val_accuracy: 0.7006
# Epoch 13/50
# 61/61 [==============================] - 0s 1ms/step - loss: 0.7113 - accuracy: 0.7206 - val_loss: 0.7477 - val_accuracy: 0.7110
# Epoch 14/50
# 61/61 [==============================] - 0s 1ms/step - loss: 0.7034 - accuracy: 0.7248 - val_loss: 0.7430 - val_accuracy: 0.7152
# Epoch 15/50
# 61/61 [==============================] - 0s 1ms/step - loss: 0.6947 - accuracy: 0.7253 - val_loss: 0.7416 - val_accuracy: 0.7048
# Epoch 16/50
# 61/61 [==============================] - 0s 1ms/step - loss: 0.6871 - accuracy: 0.7331 - val_loss: 0.7366 - val_accuracy: 0.7110
# Epoch 17/50
# 61/61 [==============================] - 0s 1ms/step - loss: 0.6791 - accuracy: 0.7326 - val_loss: 0.7367 - val_accuracy: 0.7110
# Epoch 18/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.6728 - accuracy: 0.7373 - val_loss: 0.7361 - val_accuracy: 0.7027
# Epoch 19/50
# 61/61 [==============================] - 0s 1ms/step - loss: 0.6690 - accuracy: 0.7341 - val_loss: 0.7349 - val_accuracy: 0.7131
# Epoch 20/50
# 61/61 [==============================] - 0s 1ms/step - loss: 0.6639 - accuracy: 0.7357 - val_loss: 0.7311 - val_accuracy: 0.7193
# Epoch 21/50
# 61/61 [==============================] - 0s 1ms/step - loss: 0.6596 - accuracy: 0.7414 - val_loss: 0.7324 - val_accuracy: 0.7069
# Epoch 22/50
# 61/61 [==============================] - 0s 1ms/step - loss: 0.6534 - accuracy: 0.7362 - val_loss: 0.7313 - val_accuracy: 0.7110
# Epoch 23/50
# 61/61 [==============================] - 0s 1ms/step - loss: 0.6478 - accuracy: 0.7445 - val_loss: 0.7282 - val_accuracy: 0.7048
# Epoch 24/50
# 61/61 [==============================] - 0s 1ms/step - loss: 0.6451 - accuracy: 0.7404 - val_loss: 0.7254 - val_accuracy: 0.7048
# Epoch 25/50
# 61/61 [==============================] - 0s 1ms/step - loss: 0.6412 - accuracy: 0.7461 - val_loss: 0.7202 - val_accuracy: 0.7089
# Epoch 26/50
# 61/61 [==============================] - 0s 1ms/step - loss: 0.6345 - accuracy: 0.7409 - val_loss: 0.7189 - val_accuracy: 0.7069
# Epoch 27/50
# 61/61 [==============================] - 0s 1ms/step - loss: 0.6311 - accuracy: 0.7456 - val_loss: 0.7265 - val_accuracy: 0.7006
# Epoch 28/50
# 61/61 [==============================] - 0s 1ms/step - loss: 0.6266 - accuracy: 0.7497 - val_loss: 0.7222 - val_accuracy: 0.7069
# Epoch 29/50
# 61/61 [==============================] - 0s 1ms/step - loss: 0.6214 - accuracy: 0.7523 - val_loss: 0.7221 - val_accuracy: 0.7089
# Epoch 30/50
# 61/61 [==============================] - 0s 1ms/step - loss: 0.6170 - accuracy: 0.7471 - val_loss: 0.7222 - val_accuracy: 0.6944
# Epoch 31/50
# 61/61 [==============================] - 0s 1ms/step - loss: 0.6109 - accuracy: 0.7565 - val_loss: 0.7321 - val_accuracy: 0.7048
# Epoch 32/50
# 61/61 [==============================] - 0s 1ms/step - loss: 0.6100 - accuracy: 0.7565 - val_loss: 0.7264 - val_accuracy: 0.7048
# Epoch 33/50
# 61/61 [==============================] - 0s 1ms/step - loss: 0.6032 - accuracy: 0.7601 - val_loss: 0.7238 - val_accuracy: 0.7089
# Epoch 34/50
# 61/61 [==============================] - 0s 1ms/step - loss: 0.6012 - accuracy: 0.7596 - val_loss: 0.7282 - val_accuracy: 0.7027
# Epoch 35/50
# 61/61 [==============================] - 0s 1ms/step - loss: 0.5951 - accuracy: 0.7596 - val_loss: 0.7243 - val_accuracy: 0.7069
# Epoch 36/50
# 61/61 [==============================] - 0s 1ms/step - loss: 0.5936 - accuracy: 0.7617 - val_loss: 0.7268 - val_accuracy: 0.7048
# Epoch 37/50
# 61/61 [==============================] - 0s 1ms/step - loss: 0.5877 - accuracy: 0.7617 - val_loss: 0.7242 - val_accuracy: 0.7193
# Epoch 38/50
# 61/61 [==============================] - 0s 1ms/step - loss: 0.5856 - accuracy: 0.7669 - val_loss: 0.7240 - val_accuracy: 0.7193
# Epoch 39/50
# 61/61 [==============================] - 0s 1ms/step - loss: 0.5830 - accuracy: 0.7659 - val_loss: 0.7301 - val_accuracy: 0.7089
# Epoch 40/50
# 61/61 [==============================] - 0s 1ms/step - loss: 0.5785 - accuracy: 0.7716 - val_loss: 0.7247 - val_accuracy: 0.7110
# Epoch 41/50
# 61/61 [==============================] - 0s 1ms/step - loss: 0.5726 - accuracy: 0.7695 - val_loss: 0.7219 - val_accuracy: 0.7193
# Epoch 42/50
# 61/61 [==============================] - 0s 1ms/step - loss: 0.5763 - accuracy: 0.7596 - val_loss: 0.7269 - val_accuracy: 0.7173
# Epoch 43/50
# 61/61 [==============================] - 0s 1ms/step - loss: 0.5687 - accuracy: 0.7700 - val_loss: 0.7259 - val_accuracy: 0.7193
# Epoch 44/50
# 61/61 [==============================] - 0s 1ms/step - loss: 0.5658 - accuracy: 0.7773 - val_loss: 0.7399 - val_accuracy: 0.7089
# Epoch 45/50
# 61/61 [==============================] - 0s 1ms/step - loss: 0.5647 - accuracy: 0.7685 - val_loss: 0.7313 - val_accuracy: 0.7193
# Epoch 46/50
# 61/61 [==============================] - 0s 1ms/step - loss: 0.5627 - accuracy: 0.7721 - val_loss: 0.7288 - val_accuracy: 0.7193
# Epoch 47/50
# 61/61 [==============================] - 0s 1ms/step - loss: 0.5570 - accuracy: 0.7784 - val_loss: 0.7327 - val_accuracy: 0.7152
# Epoch 48/50
# 61/61 [==============================] - 0s 1ms/step - loss: 0.5538 - accuracy: 0.7768 - val_loss: 0.7338 - val_accuracy: 0.7089
# Epoch 49/50
# 61/61 [==============================] - 0s 1ms/step - loss: 0.5531 - accuracy: 0.7742 - val_loss: 0.7379 - val_accuracy: 0.7048
# Epoch 50/50
# 61/61 [==============================] - 0s 1ms/step - loss: 0.5483 - accuracy: 0.7758 - val_loss: 0.7306 - val_accuracy: 0.7131
# 19/19 [==============================] - 0s 833us/step - loss: 0.7815 - accuracy: 0.7072
# Test Accuracy: 0.7071547508239746

# %%
test_data = ssscaler.fit_transform(test_data)
test_pred = model.predict(test_data)
test_pred = test_pred.argmax(axis=1)
ids = range(1, len(test_pred) + 1)

print(test_pred.shape)
# save submission file
prediction = pd.DataFrame({'id': ids, 'imdb_score_binned': test_pred})
prediction.to_csv("../Kaggle_submissions/dense_nn_notext.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 2
#       1 test_data = ssscaler.fit_transform(test_data)
# ----> 2 test_pred = model.predict(test_data)
#       3 test_pred = test_pred.argmax(axis=1)
#       4 ids = range(1, len(test_pred) + 1)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\AppData\Local\Temp\__autograph_generated_file_6k5jrrs.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__predict_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# ValueError: in user code:
#
#     File "C:\Users\Steven\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py", line 2440, in predict_function  *
#         return step_function(self, iterator)
#     File "C:\Users\Steven\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py", line 2425, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\Steven\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py", line 2413, in run_step  **
#         outputs = model.predict_step(data)
#     File "C:\Users\Steven\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py", line 2381, in predict_step
#         return self(x, training=False)
#     File "C:\Users\Steven\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "C:\Users\Steven\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\input_spec.py", line 298, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "sequential_1" is incompatible with the layer: expected shape=(None, 21), found shape=(None, 6)
