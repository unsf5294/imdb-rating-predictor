# %% [markdown]
# ### 4. Random Forest 🌳
# ##### working on it

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# #### 4.1 Random forest using a simple preprocess with low dimensionality and many columns removed.
# ##### AKA data_no_text

# %%
# first use the basic no text data
data = pd.read_csv("../COMP30027_2024_asst2_data/train_dataset_no_text.csv")
test_data = pd.read_csv("../COMP30027_2024_asst2_data/test_dataset_no_text.csv")
# drop id before calculation, add back after
data = data.drop(columns=['id'])
test_data = test_data.drop(columns=['id'])

# %%
# split the data

X = data.drop(columns=["imdb_score_binned"])
y = data["imdb_score_binned"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=715)

rf = RandomForestClassifier(random_state=715)

# %%
rf.fit(X_train, y_train)
predictions = rf.predict(X_test)

accuracy = accuracy_score(y_test, predictions)

print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7071547420965059

# %%
scores = cross_val_score(rf, X, y, cv=10)
print("Scores:", scores.mean())
# Out:
# Scores: 0.7200376522702104

# %% [markdown]
# #### Kaggle prediction on test data

# %%
# make prediction on test

test_pred = rf.predict(test_data)
ids = range(1, len(test_pred) + 1)

# save submission file
prediction = pd.DataFrame({'id': ids, 'imdb_score_binned': test_pred})
prediction.to_csv("../Kaggle_submissions/RF_no_text.csv", index=False)

# %% [markdown]
# #### 4.2 RF using entire dataset

# %%
data_full = pd.read_csv("../COMP30027_2024_asst2_data/train_select.csv")
data_full = data_full.drop(columns='id')

# %%
# split the data
X = data_full.drop(columns=["imdb_score_binned"])
y = data_full["imdb_score_binned"]


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=715)

rf = RandomForestClassifier(random_state=715)

# %%
rf.fit(X_train, y_train)
predictions = rf.predict(X_test)

accuracy = accuracy_score(y_test, predictions)

print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7088186356073212

# %%
scores = cross_val_score(rf, X, y, cv=10)
print("Scores:", scores.mean())
# Out:
# Scores: 0.727027685492802

# %%
rf = RandomForestClassifier(random_state=715, max_depth=10, n_estimators=500)
rf.fit(X, y)

test_pred = rf.predict(test_data)
ids = range(1, len(test_pred) + 1)

# save submission file
prediction = pd.DataFrame({'id': ids, 'imdb_score_binned': test_pred})
prediction.to_csv("../Kaggle_submissions/RF_full_select.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [14], line 4
#       1 rf = RandomForestClassifier(random_state=715, max_depth=10, n_estimators=500)
#       2 rf.fit(X, y)
# ----> 4 test_pred = rf.predict(test_data)
#       5 ids = range(1, len(test_pred) + 1)
#       7 # save submission file
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_forest.py:820, in ForestClassifier.predict(self, X)
#     799 def predict(self, X):
#     800     """
#     801     Predict class for X.
#     802
#    (...)
#     818         The predicted classes.
#     819     """
# --> 820     proba = self.predict_proba(X)
#     822     if self.n_outputs_ == 1:
#     823         return self.classes_.take(np.argmax(proba, axis=1), axis=0)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_forest.py:862, in ForestClassifier.predict_proba(self, X)
#     860 check_is_fitted(self)
#     861 # Check data
# --> 862 X = self._validate_X_predict(X)
#     864 # Assign chunk of trees to jobs
#     865 n_jobs, _, _ = _partition_estimators(self.n_estimators, self.n_jobs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_forest.py:602, in BaseForest._validate_X_predict(self, X)
#     599 """
#     600 Validate X whenever one tries to predict, apply, predict_proba."""
#     601 check_is_fitted(self)
# --> 602 X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
#     603 if issparse(X) and (X.indices.dtype != np.intc or X.indptr.dtype != np.intc):
#     604     raise ValueError("No support for np.int64 index based sparse matrices")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:548, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     483 def _validate_data(
#     484     self,
#     485     X="no_validation",
#    (...)
#     489     **check_params,
#     490 ):
#     491     """Validate input data and set or check the `n_features_in_` attribute.
#     492
#     493     Parameters
#    (...)
#     546         validated.
#     547     """
# --> 548     self._check_feature_names(X, reset=reset)
#     550     if y is None and self._get_tags()["requires_y"]:
#     551         raise ValueError(
#     552             f"This {self.__class__.__name__} estimator "
#     553             "requires y to be passed, but the target y is None."
#     554         )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:481, in BaseEstimator._check_feature_names(self, X, reset)
#     476 if not missing_names and not unexpected_names:
#     477     message += (
#     478         "Feature names must be in the same order as they were in fit.\n"
#     479     )
# --> 481 raise ValueError(message)
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names unseen at fit time:
# - genres
# - plot_keywords
# Feature names seen at fit time, yet now missing:
# - actor_1_name_Anjelica Huston
# - actor_1_name_Brendan Fraser
# - actor_1_name_Catherine Deneuve
# - actor_1_name_Christopher Lee
# - actor_1_name_David Oyelowo
# - ...
